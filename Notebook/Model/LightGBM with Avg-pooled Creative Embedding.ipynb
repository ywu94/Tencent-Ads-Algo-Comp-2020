# %%
import os
train_path = '../../raw_train_artifact'
test_path = '../../raw_test_artifact'
input_path = '../../input_artifact'
model_path = '../../model_artifact'
if not os.path.isdir(model_path): os.mkdir(model_path)

# %%
import sys
import gc
import time
import numpy as np

import pandas as pd
pd.set_option('display.max_columns',120)
pd.set_option('display.max_rows',2000)
pd.set_option('precision',5)
pd.set_option('float_format', '{:.5f}'.format)

import tqdm
import joblib
import json

from lightgbm import LGBMClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, roc_auc_score

# %%
import logging

log_path = 'LightGBM with Avg-pooled Creative Embedding.log'
if os.path.isfile(log_path): os.remove(log_path)
    
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)

formatter = logging.Formatter('%(asctime)s %(levelname)-s: %(message)s', datefmt='%H:%M:%S')

fh = logging.FileHandler(log_path)
fh.setLevel(logging.INFO)
fh.setFormatter(formatter)
logger.addHandler(fh)

sh = logging.StreamHandler(sys.stdout)
sh.setLevel(logging.INFO)
sh.setFormatter(formatter)
logger.addHandler(sh)

# %% [markdown]
# ## Load Data

# %%
age_path = os.path.join(input_path, 'tag_age.npy')
with open(age_path, 'rb') as f:
    tag_age = np.load(f)

# %%
gender_path = os.path.join(input_path, 'tag_gender.npy')
with open(gender_path, 'rb') as f:
    tag_gender = np.load(f)

# %%
avg_pool_file_path = os.path.join(input_path, 'input_creative_avg_pool.npy')
with open(avg_pool_file_path, 'rb') as f:
    inp = np.load(f)

# %% [markdown]
# ## Age Model

# %%
N_FOLD = 5

folds = KFold(n_splits=N_FOLD, shuffle=True, random_state=1898)
oof_pred = np.zeros(inp.shape[0])
gc.enable()

for n_iter, (train_idx, test_idx) in enumerate(folds.split(inp)):
    x_train, y_train = inp[train_idx,:], tag_age[train_idx]
    x_test, y_test = inp[test_idx,:], tag_age[test_idx]
    
    logger.info(f'Fold {n_iter+1}/{N_FOLD}')
    start = time.time()
    
    clf = LGBMClassifier(
        n_estimators=5000,
        learning_rate=0.01,
        num_leaves=128,
        colsample_bytree=.8,
        subsample=.9,
        max_depth=15,
        reg_alpha=.1,
        reg_lambda=.1,
        min_split_gain=.01,
        min_child_weight=2,
        random_state=1898,
        objective='multiclass'
    )
    
    clf.fit(x_train, y_train, 
            eval_set= [(x_train, y_train), (x_test, y_test)], 
            eval_metric='multi_logloss', verbose=250, early_stopping_rounds=150
    )
    
    logger.info(f'Model training is done after {time.time()-start:.2f}s')
    
    oof_pred[test_idx] = clf.predict(x_test, num_iteration=clf.best_iteration_)
    cur_accuracy = accuracy_score(y_test, oof_pred[test_idx])
    logger.info(f'OOF Accuracy: {cur_accuracy:.6f}')
    
    gbm_artifact = f'GBM_Creative_Age_{n_iter+1}.pkl'
    joblib.dump(clf, os.path.join(model_path, gbm_artifact))
    
    del clf, x_train, y_train, x_test, y_test
    gc.collect()
    
full_accuracy = accuracy_score(tag_age, oof_pred)

logger.info(f'Total OOF Accuracy: {full_accuracy:.6f}')
# Out:
# 23:50:15 INFO: Fold 1/5
# Training until validation scores don't improve for 150 rounds
# [250]	training's multi_logloss: 1.66998	valid_1's multi_logloss: 1.71677
# [500]	training's multi_logloss: 1.55583	valid_1's multi_logloss: 1.63458
# [750]	training's multi_logloss: 1.48901	valid_1's multi_logloss: 1.59768
# [1000]	training's multi_logloss: 1.43936	valid_1's multi_logloss: 1.57686
# [1250]	training's multi_logloss: 1.39826	valid_1's multi_logloss: 1.56351
# [1500]	training's multi_logloss: 1.36224	valid_1's multi_logloss: 1.55424
# [1750]	training's multi_logloss: 1.32978	valid_1's multi_logloss: 1.54742
# [2000]	training's multi_logloss: 1.29999	valid_1's multi_logloss: 1.54223
# [2250]	training's multi_logloss: 1.27246	valid_1's multi_logloss: 1.53832
# [2500]	training's multi_logloss: 1.24686	valid_1's multi_logloss: 1.53534
# [2750]	training's multi_logloss: 1.22308	valid_1's multi_logloss: 1.5332
# [3000]	training's multi_logloss: 1.20088	valid_1's multi_logloss: 1.53158
# [3250]	training's multi_logloss: 1.18002	valid_1's multi_logloss: 1.53045
# [3500]	training's multi_logloss: 1.16023	valid_1's multi_logloss: 1.52961
# [3750]	training's multi_logloss: 1.14144	valid_1's multi_logloss: 1.52901
# [4000]	training's multi_logloss: 1.12342	valid_1's multi_logloss: 1.52859
# [4250]	training's multi_logloss: 1.10607	valid_1's multi_logloss: 1.52831
# [4500]	training's multi_logloss: 1.08931	valid_1's multi_logloss: 1.5281
# [4750]	training's multi_logloss: 1.07303	valid_1's multi_logloss: 1.52798
# [5000]	training's multi_logloss: 1.05729	valid_1's multi_logloss: 1.52793
# Did not meet early stopping. Best iteration is:
# [5000]	training's multi_logloss: 1.05729	valid_1's multi_logloss: 1.52793
# 04:01:46 INFO: Model training is done after 15090.23s
# 04:11:42 INFO: OOF Accuracy: 0.372689
# 04:12:02 INFO: Fold 2/5
# Training until validation scores don't improve for 150 rounds
# [250]	training's multi_logloss: 1.67051	valid_1's multi_logloss: 1.71497
# [500]	training's multi_logloss: 1.55631	valid_1's multi_logloss: 1.63254
# [750]	training's multi_logloss: 1.48942	valid_1's multi_logloss: 1.59585
# [1000]	training's multi_logloss: 1.43978	valid_1's multi_logloss: 1.5751
# [1250]	training's multi_logloss: 1.39864	valid_1's multi_logloss: 1.56175
# [1500]	training's multi_logloss: 1.36265	valid_1's multi_logloss: 1.55252
# [1750]	training's multi_logloss: 1.33021	valid_1's multi_logloss: 1.54572
# [2000]	training's multi_logloss: 1.30044	valid_1's multi_logloss: 1.54061
# [2250]	training's multi_logloss: 1.27291	valid_1's multi_logloss: 1.53674
# [2500]	training's multi_logloss: 1.24742	valid_1's multi_logloss: 1.53387
# [2750]	training's multi_logloss: 1.22367	valid_1's multi_logloss: 1.53172
# [3000]	training's multi_logloss: 1.20139	valid_1's multi_logloss: 1.53017
# [3250]	training's multi_logloss: 1.1805	valid_1's multi_logloss: 1.52908
# [3500]	training's multi_logloss: 1.16063	valid_1's multi_logloss: 1.52831
# [3750]	training's multi_logloss: 1.14171	valid_1's multi_logloss: 1.52776
# [4000]	training's multi_logloss: 1.12356	valid_1's multi_logloss: 1.52736
# [4250]	training's multi_logloss: 1.1061	valid_1's multi_logloss: 1.52707
# [4500]	training's multi_logloss: 1.08916	valid_1's multi_logloss: 1.52684
# [4750]	training's multi_logloss: 1.07291	valid_1's multi_logloss: 1.52676
# [5000]	training's multi_logloss: 1.05703	valid_1's multi_logloss: 1.52668
# Did not meet early stopping. Best iteration is:
# [5000]	training's multi_logloss: 1.05703	valid_1's multi_logloss: 1.52668
# 08:23:40 INFO: Model training is done after 15097.80s
# 08:33:36 INFO: OOF Accuracy: 0.372256
# 08:33:56 INFO: Fold 3/5
# Training until validation scores don't improve for 150 rounds
# [250]	training's multi_logloss: 1.67112	valid_1's multi_logloss: 1.71381
# [500]	training's multi_logloss: 1.55703	valid_1's multi_logloss: 1.63085
# [750]	training's multi_logloss: 1.49021	valid_1's multi_logloss: 1.59363
# [1000]	training's multi_logloss: 1.44055	valid_1's multi_logloss: 1.57266
# [1250]	training's multi_logloss: 1.39943	valid_1's multi_logloss: 1.55917
# [1500]	training's multi_logloss: 1.36338	valid_1's multi_logloss: 1.54976
# [1750]	training's multi_logloss: 1.33088	valid_1's multi_logloss: 1.54293
# [2000]	training's multi_logloss: 1.30109	valid_1's multi_logloss: 1.53777
# [2250]	training's multi_logloss: 1.27358	valid_1's multi_logloss: 1.53375
# [2500]	training's multi_logloss: 1.24809	valid_1's multi_logloss: 1.53078
# [2750]	training's multi_logloss: 1.2243	valid_1's multi_logloss: 1.52855
# [3000]	training's multi_logloss: 1.20212	valid_1's multi_logloss: 1.52694
# [3250]	training's multi_logloss: 1.18122	valid_1's multi_logloss: 1.52571
# [3500]	training's multi_logloss: 1.16141	valid_1's multi_logloss: 1.52488
# [3750]	training's multi_logloss: 1.14253	valid_1's multi_logloss: 1.52424
# [4000]	training's multi_logloss: 1.12445	valid_1's multi_logloss: 1.52378
# [4250]	training's multi_logloss: 1.10697	valid_1's multi_logloss: 1.52345
# [4500]	training's multi_logloss: 1.09001	valid_1's multi_logloss: 1.52318
# [4750]	training's multi_logloss: 1.07362	valid_1's multi_logloss: 1.52301
# [5000]	training's multi_logloss: 1.05776	valid_1's multi_logloss: 1.52293
# Did not meet early stopping. Best iteration is:
# [5000]	training's multi_logloss: 1.05776	valid_1's multi_logloss: 1.52293
# 12:45:13 INFO: Model training is done after 15076.67s
# 12:55:10 INFO: OOF Accuracy: 0.372972
# 12:55:30 INFO: Fold 4/5
# Training until validation scores don't improve for 150 rounds
# [250]	training's multi_logloss: 1.67091	valid_1's multi_logloss: 1.71324
# [500]	training's multi_logloss: 1.55692	valid_1's multi_logloss: 1.63049
# [750]	training's multi_logloss: 1.49021	valid_1's multi_logloss: 1.59331
# [1000]	training's multi_logloss: 1.4406	valid_1's multi_logloss: 1.57227
# [1250]	training's multi_logloss: 1.39945	valid_1's multi_logloss: 1.55881
# [1500]	training's multi_logloss: 1.36343	valid_1's multi_logloss: 1.54954
# [1750]	training's multi_logloss: 1.33093	valid_1's multi_logloss: 1.54266
# [2000]	training's multi_logloss: 1.30112	valid_1's multi_logloss: 1.53747
# [2250]	training's multi_logloss: 1.27356	valid_1's multi_logloss: 1.53351
# [2500]	training's multi_logloss: 1.24798	valid_1's multi_logloss: 1.53056
# [2750]	training's multi_logloss: 1.2242	valid_1's multi_logloss: 1.52836
# [3000]	training's multi_logloss: 1.20193	valid_1's multi_logloss: 1.52681
# [3250]	training's multi_logloss: 1.18097	valid_1's multi_logloss: 1.52564
# [3500]	training's multi_logloss: 1.16112	valid_1's multi_logloss: 1.52483
# [3750]	training's multi_logloss: 1.1423	valid_1's multi_logloss: 1.52421
# [4000]	training's multi_logloss: 1.12425	valid_1's multi_logloss: 1.52381
# [4250]	training's multi_logloss: 1.1068	valid_1's multi_logloss: 1.5235
# [4500]	training's multi_logloss: 1.08998	valid_1's multi_logloss: 1.52327
# [4750]	training's multi_logloss: 1.07359	valid_1's multi_logloss: 1.52316
# [5000]	training's multi_logloss: 1.05771	valid_1's multi_logloss: 1.52311
# Did not meet early stopping. Best iteration is:
# [5000]	training's multi_logloss: 1.05771	valid_1's multi_logloss: 1.52311
# 17:06:55 INFO: Model training is done after 15084.92s
# 17:16:33 INFO: OOF Accuracy: 0.374239
# 17:16:53 INFO: Fold 5/5
# Training until validation scores don't improve for 150 rounds
# [250]	training's multi_logloss: 1.67076	valid_1's multi_logloss: 1.71386
# [500]	training's multi_logloss: 1.55665	valid_1's multi_logloss: 1.63136
# [750]	training's multi_logloss: 1.48994	valid_1's multi_logloss: 1.59438
# [1000]	training's multi_logloss: 1.44026	valid_1's multi_logloss: 1.57351
# [1250]	training's multi_logloss: 1.39908	valid_1's multi_logloss: 1.56014
# [1500]	training's multi_logloss: 1.363	valid_1's multi_logloss: 1.55091
# [1750]	training's multi_logloss: 1.3305	valid_1's multi_logloss: 1.54405
# [2000]	training's multi_logloss: 1.3007	valid_1's multi_logloss: 1.53887
# [2250]	training's multi_logloss: 1.27318	valid_1's multi_logloss: 1.5349
# [2500]	training's multi_logloss: 1.24763	valid_1's multi_logloss: 1.53188
# [2750]	training's multi_logloss: 1.22376	valid_1's multi_logloss: 1.52966
# [3000]	training's multi_logloss: 1.2015	valid_1's multi_logloss: 1.52803
# [3250]	training's multi_logloss: 1.18058	valid_1's multi_logloss: 1.52683
# [3500]	training's multi_logloss: 1.1608	valid_1's multi_logloss: 1.52602
# [3750]	training's multi_logloss: 1.14195	valid_1's multi_logloss: 1.5254
# [4000]	training's multi_logloss: 1.12397	valid_1's multi_logloss: 1.52499
# [4250]	training's multi_logloss: 1.10649	valid_1's multi_logloss: 1.52464
# [4500]	training's multi_logloss: 1.08968	valid_1's multi_logloss: 1.52444
# [4750]	training's multi_logloss: 1.07331	valid_1's multi_logloss: 1.52427
# [5000]	training's multi_logloss: 1.05746	valid_1's multi_logloss: 1.52422
# Did not meet early stopping. Best iteration is:
# [5000]	training's multi_logloss: 1.05746	valid_1's multi_logloss: 1.52422
# 21:32:25 INFO: Model training is done after 15332.05s
# 21:43:08 INFO: OOF Accuracy: 0.372594
# 21:43:28 INFO: Total OOF Accuracy: 0.372950

# %% [markdown]
# ## Gender Model

# %%
N_FOLD = 5

folds = KFold(n_splits=N_FOLD, shuffle=True, random_state=1898)
oof_pred = np.zeros(inp.shape[0])
oof_pred_prob = np.zeros(inp.shape[0])

gc.enable()

for n_iter, (train_idx, test_idx) in enumerate(folds.split(inp)):
    x_train, y_train = inp[train_idx,:], tag_gender[train_idx]
    x_test, y_test = inp[test_idx,:], tag_gender[test_idx]
    
    logger.info(f'Fold {n_iter+1}/{N_FOLD}')
    start = time.time()
    
    clf = LGBMClassifier(
        n_estimators=5000,
        learning_rate=0.01,
        num_leaves=128,
        colsample_bytree=.8,
        subsample=.9,
        max_depth=15,
        reg_alpha=.1,
        reg_lambda=.1,
        min_split_gain=.01,
        min_child_weight=2,
        random_state=1898
    )
    
    clf.fit(x_train, y_train, 
            eval_set= [(x_train, y_train), (x_test, y_test)], 
            eval_metric='auc', verbose=250, early_stopping_rounds=150
    )
    
    logger.info(f'Model training is done after {time.time()-start:.2f}s')
    
    oof_pred[test_idx] = clf.predict(x_test, num_iteration=clf.best_iteration_)
    oof_pred_prob[test_idx] = clf.predict_proba(x_test, num_iteration=clf.best_iteration_)[:,1]
    cur_accuracy = accuracy_score(y_test, oof_pred[test_idx])
    cur_auc = roc_auc_score(y_test, oof_pred_prob[test_idx])
    logger.info(f'OOF Accuracy: {cur_accuracy:.6f}, AUC: {cur_auc:.6f}')
    
    gbm_artifact = f'GBM_Creative_Gender_{n_iter+1}.pkl'
    joblib.dump(clf, os.path.join(model_path, gbm_artifact))
    
    del clf, x_train, y_train, x_test, y_test
    gc.collect()
    
full_accuracy = accuracy_score(tag_gender, oof_pred)
full_auc = roc_auc_score(tag_gender, oof_pred_prob)

logger.info(f'Total OOF Accuracy: {full_accuracy:.6f}, AUC: {full_auc:.6f}')
# Out:
# 21:43:29 INFO: Fold 1/5
# Training until validation scores don't improve for 150 rounds
# [250]	training's auc: 0.955673	training's binary_logloss: 0.275063	valid_1's auc: 0.952709	valid_1's binary_logloss: 0.281623
# [500]	training's auc: 0.962635	training's binary_logloss: 0.233767	valid_1's auc: 0.958428	valid_1's binary_logloss: 0.245256
# [750]	training's auc: 0.966587	training's binary_logloss: 0.218171	valid_1's auc: 0.961024	valid_1's binary_logloss: 0.234585
# [1000]	training's auc: 0.969581	training's binary_logloss: 0.207826	valid_1's auc: 0.962565	valid_1's binary_logloss: 0.229153
# [1250]	training's auc: 0.972097	training's binary_logloss: 0.199549	valid_1's auc: 0.96355	valid_1's binary_logloss: 0.22581
# [1500]	training's auc: 0.974255	training's binary_logloss: 0.192463	valid_1's auc: 0.964253	valid_1's binary_logloss: 0.223412
# [1750]	training's auc: 0.976171	training's binary_logloss: 0.186147	valid_1's auc: 0.964757	valid_1's binary_logloss: 0.221657
# [2000]	training's auc: 0.977838	training's binary_logloss: 0.180468	valid_1's auc: 0.965119	valid_1's binary_logloss: 0.220357
# [2250]	training's auc: 0.979331	training's binary_logloss: 0.175262	valid_1's auc: 0.965386	valid_1's binary_logloss: 0.21938
# [2500]	training's auc: 0.980698	training's binary_logloss: 0.170456	valid_1's auc: 0.965586	valid_1's binary_logloss: 0.218633
# [2750]	training's auc: 0.981925	training's binary_logloss: 0.16609	valid_1's auc: 0.965722	valid_1's binary_logloss: 0.218134
# [3000]	training's auc: 0.98303	training's binary_logloss: 0.162107	valid_1's auc: 0.965805	valid_1's binary_logloss: 0.217819
# [3250]	training's auc: 0.984056	training's binary_logloss: 0.158344	valid_1's auc: 0.965884	valid_1's binary_logloss: 0.217532
# [3500]	training's auc: 0.984998	training's binary_logloss: 0.154778	valid_1's auc: 0.965946	valid_1's binary_logloss: 0.217305
# [3750]	training's auc: 0.985881	training's binary_logloss: 0.151338	valid_1's auc: 0.965996	valid_1's binary_logloss: 0.217118
# [4000]	training's auc: 0.986687	training's binary_logloss: 0.148096	valid_1's auc: 0.966036	valid_1's binary_logloss: 0.216967
# [4250]	training's auc: 0.987496	training's binary_logloss: 0.144832	valid_1's auc: 0.96609	valid_1's binary_logloss: 0.216778
# [4500]	training's auc: 0.98824	training's binary_logloss: 0.14172	valid_1's auc: 0.96613	valid_1's binary_logloss: 0.216629
# [4750]	training's auc: 0.988939	training's binary_logloss: 0.138692	valid_1's auc: 0.966169	valid_1's binary_logloss: 0.216494
# [5000]	training's auc: 0.989601	training's binary_logloss: 0.13578	valid_1's auc: 0.966195	valid_1's binary_logloss: 0.216394
# Did not meet early stopping. Best iteration is:
# [5000]	training's auc: 0.989601	training's binary_logloss: 0.13578	valid_1's auc: 0.966195	valid_1's binary_logloss: 0.216394
# 22:13:59 INFO: Model training is done after 1830.14s
# 22:15:29 INFO: OOF Accuracy: 0.917622, AUC: 0.966195
# 22:15:32 INFO: Fold 2/5
# Training until validation scores don't improve for 150 rounds
# [250]	training's auc: 0.955767	training's binary_logloss: 0.27505	valid_1's auc: 0.952505	valid_1's binary_logloss: 0.28136
# [500]	training's auc: 0.962662	training's binary_logloss: 0.233859	valid_1's auc: 0.958367	valid_1's binary_logloss: 0.244793
# [750]	training's auc: 0.966591	training's binary_logloss: 0.218304	valid_1's auc: 0.961069	valid_1's binary_logloss: 0.233896
# [1000]	training's auc: 0.969553	training's binary_logloss: 0.208014	valid_1's auc: 0.962633	valid_1's binary_logloss: 0.228404
# [1250]	training's auc: 0.972066	training's binary_logloss: 0.199735	valid_1's auc: 0.963629	valid_1's binary_logloss: 0.225016
# [1500]	training's auc: 0.974216	training's binary_logloss: 0.192674	valid_1's auc: 0.964316	valid_1's binary_logloss: 0.22268
# [1750]	training's auc: 0.976115	training's binary_logloss: 0.186381	valid_1's auc: 0.964809	valid_1's binary_logloss: 0.220966
# [2000]	training's auc: 0.977807	training's binary_logloss: 0.180655	valid_1's auc: 0.965181	valid_1's binary_logloss: 0.219654
# [2250]	training's auc: 0.979331	training's binary_logloss: 0.175383	valid_1's auc: 0.965474	valid_1's binary_logloss: 0.218607
# [2500]	training's auc: 0.980702	training's binary_logloss: 0.170592	valid_1's auc: 0.965675	valid_1's binary_logloss: 0.217882
# [2750]	training's auc: 0.981928	training's binary_logloss: 0.166254	valid_1's auc: 0.965789	valid_1's binary_logloss: 0.217445
# [3000]	training's auc: 0.98306	training's binary_logloss: 0.162185	valid_1's auc: 0.965874	valid_1's binary_logloss: 0.217125
# [3250]	training's auc: 0.984092	training's binary_logloss: 0.158389	valid_1's auc: 0.965944	valid_1's binary_logloss: 0.216861
# [3500]	training's auc: 0.985082	training's binary_logloss: 0.154689	valid_1's auc: 0.966003	valid_1's binary_logloss: 0.216631
# [3750]	training's auc: 0.985944	training's binary_logloss: 0.15129	valid_1's auc: 0.966054	valid_1's binary_logloss: 0.216435
# [4000]	training's auc: 0.986762	training's binary_logloss: 0.147987	valid_1's auc: 0.966094	valid_1's binary_logloss: 0.216283
# [4250]	training's auc: 0.98755	training's binary_logloss: 0.144779	valid_1's auc: 0.966132	valid_1's binary_logloss: 0.216141
# [4500]	training's auc: 0.988322	training's binary_logloss: 0.141591	valid_1's auc: 0.966167	valid_1's binary_logloss: 0.216006
# [4750]	training's auc: 0.989023	training's binary_logloss: 0.138554	valid_1's auc: 0.966205	valid_1's binary_logloss: 0.215873
# [5000]	training's auc: 0.989674	training's binary_logloss: 0.135635	valid_1's auc: 0.966228	valid_1's binary_logloss: 0.215791
# Did not meet early stopping. Best iteration is:
# [5000]	training's auc: 0.989674	training's binary_logloss: 0.135635	valid_1's auc: 0.966228	valid_1's binary_logloss: 0.215791
# 22:46:30 INFO: Model training is done after 1857.97s
# 22:48:09 INFO: OOF Accuracy: 0.917389, AUC: 0.966228
# 22:48:12 INFO: Fold 3/5
# Training until validation scores don't improve for 150 rounds
# [250]	training's auc: 0.955676	training's binary_logloss: 0.275269	valid_1's auc: 0.952926	valid_1's binary_logloss: 0.280419
# [500]	training's auc: 0.96261	training's binary_logloss: 0.234036	valid_1's auc: 0.958537	valid_1's binary_logloss: 0.244131
# [750]	training's auc: 0.966568	training's binary_logloss: 0.218439	valid_1's auc: 0.961146	valid_1's binary_logloss: 0.233485
# [1000]	training's auc: 0.969554	training's binary_logloss: 0.208121	valid_1's auc: 0.962677	valid_1's binary_logloss: 0.228145
# [1250]	training's auc: 0.972059	training's binary_logloss: 0.199837	valid_1's auc: 0.963676	valid_1's binary_logloss: 0.224768
# [1500]	training's auc: 0.974222	training's binary_logloss: 0.192754	valid_1's auc: 0.964367	valid_1's binary_logloss: 0.222422
# [1750]	training's auc: 0.976114	training's binary_logloss: 0.186461	valid_1's auc: 0.964884	valid_1's binary_logloss: 0.220655
# [2000]	training's auc: 0.977788	training's binary_logloss: 0.18079	valid_1's auc: 0.965257	valid_1's binary_logloss: 0.219341
# [2250]	training's auc: 0.979294	training's binary_logloss: 0.175552	valid_1's auc: 0.965547	valid_1's binary_logloss: 0.21833
# [2500]	training's auc: 0.980648	training's binary_logloss: 0.170799	valid_1's auc: 0.965746	valid_1's binary_logloss: 0.217606
# [2750]	training's auc: 0.981839	training's binary_logloss: 0.166545	valid_1's auc: 0.965858	valid_1's binary_logloss: 0.217186
# [3000]	training's auc: 0.982956	training's binary_logloss: 0.162519	valid_1's auc: 0.965946	valid_1's binary_logloss: 0.216848
# [3250]	training's auc: 0.983968	training's binary_logloss: 0.158735	valid_1's auc: 0.966015	valid_1's binary_logloss: 0.216582
# [3500]	training's auc: 0.984915	training's binary_logloss: 0.15513	valid_1's auc: 0.966072	valid_1's binary_logloss: 0.216352
# [3750]	training's auc: 0.985788	training's binary_logloss: 0.151698	valid_1's auc: 0.966117	valid_1's binary_logloss: 0.216165
# [4000]	training's auc: 0.986593	training's binary_logloss: 0.148416	valid_1's auc: 0.966161	valid_1's binary_logloss: 0.215997
# [4250]	training's auc: 0.987372	training's binary_logloss: 0.145226	valid_1's auc: 0.966202	valid_1's binary_logloss: 0.215841
# [4500]	training's auc: 0.988099	training's binary_logloss: 0.142145	valid_1's auc: 0.966242	valid_1's binary_logloss: 0.215698
# [4750]	training's auc: 0.988799	training's binary_logloss: 0.139138	valid_1's auc: 0.966273	valid_1's binary_logloss: 0.215593
# [5000]	training's auc: 0.989462	training's binary_logloss: 0.136218	valid_1's auc: 0.966292	valid_1's binary_logloss: 0.215515
# Did not meet early stopping. Best iteration is:
# [5000]	training's auc: 0.989462	training's binary_logloss: 0.136218	valid_1's auc: 0.966292	valid_1's binary_logloss: 0.215515
# 23:19:12 INFO: Model training is done after 1860.49s
# 23:20:43 INFO: OOF Accuracy: 0.917528, AUC: 0.966292
# 23:20:46 INFO: Fold 4/5
# Training until validation scores don't improve for 150 rounds
# [250]	training's auc: 0.955753	training's binary_logloss: 0.275146	valid_1's auc: 0.952672	valid_1's binary_logloss: 0.280786
# [500]	training's auc: 0.962681	training's binary_logloss: 0.233849	valid_1's auc: 0.95837	valid_1's binary_logloss: 0.244606
# [750]	training's auc: 0.966638	training's binary_logloss: 0.218189	valid_1's auc: 0.960944	valid_1's binary_logloss: 0.234044
# [1000]	training's auc: 0.969611	training's binary_logloss: 0.207869	valid_1's auc: 0.962433	valid_1's binary_logloss: 0.228813
# [1250]	training's auc: 0.972133	training's binary_logloss: 0.199569	valid_1's auc: 0.963407	valid_1's binary_logloss: 0.225507
# [1500]	training's auc: 0.974292	training's binary_logloss: 0.192468	valid_1's auc: 0.964078	valid_1's binary_logloss: 0.223219
# [1750]	training's auc: 0.976211	training's binary_logloss: 0.186123	valid_1's auc: 0.964571	valid_1's binary_logloss: 0.221516
# [2000]	training's auc: 0.977887	training's binary_logloss: 0.18041	valid_1's auc: 0.964931	valid_1's binary_logloss: 0.220259
# [2250]	training's auc: 0.97941	training's binary_logloss: 0.175156	valid_1's auc: 0.965216	valid_1's binary_logloss: 0.219267
# [2500]	training's auc: 0.980757	training's binary_logloss: 0.17038	valid_1's auc: 0.965423	valid_1's binary_logloss: 0.218534
# [2750]	training's auc: 0.981951	training's binary_logloss: 0.166065	valid_1's auc: 0.965544	valid_1's binary_logloss: 0.218096
# [3000]	training's auc: 0.98303	training's binary_logloss: 0.162144	valid_1's auc: 0.965608	valid_1's binary_logloss: 0.217838
# [3250]	training's auc: 0.984051	training's binary_logloss: 0.158381	valid_1's auc: 0.965674	valid_1's binary_logloss: 0.217593
# [3500]	training's auc: 0.984991	training's binary_logloss: 0.154818	valid_1's auc: 0.965731	valid_1's binary_logloss: 0.217388
# [3750]	training's auc: 0.98588	training's binary_logloss: 0.15137	valid_1's auc: 0.96578	valid_1's binary_logloss: 0.217211
# [4000]	training's auc: 0.986699	training's binary_logloss: 0.148083	valid_1's auc: 0.96582	valid_1's binary_logloss: 0.217072
# [4250]	training's auc: 0.987494	training's binary_logloss: 0.144845	valid_1's auc: 0.965861	valid_1's binary_logloss: 0.216939
# [4500]	training's auc: 0.988217	training's binary_logloss: 0.141787	valid_1's auc: 0.965893	valid_1's binary_logloss: 0.216825
# [4750]	training's auc: 0.988924	training's binary_logloss: 0.138751	valid_1's auc: 0.965927	valid_1's binary_logloss: 0.216711
# [5000]	training's auc: 0.989585	training's binary_logloss: 0.135812	valid_1's auc: 0.965964	valid_1's binary_logloss: 0.216592
# Did not meet early stopping. Best iteration is:
# [5000]	training's auc: 0.989585	training's binary_logloss: 0.135812	valid_1's auc: 0.965964	valid_1's binary_logloss: 0.216592
# 23:51:22 INFO: Model training is done after 1836.69s
# 23:52:54 INFO: OOF Accuracy: 0.917844, AUC: 0.965964
# 23:52:57 INFO: Fold 5/5
# Training until validation scores don't improve for 150 rounds
# [250]	training's auc: 0.955644	training's binary_logloss: 0.275277	valid_1's auc: 0.952881	valid_1's binary_logloss: 0.280638
# [500]	training's auc: 0.962614	training's binary_logloss: 0.23402	valid_1's auc: 0.958774	valid_1's binary_logloss: 0.243886
# [750]	training's auc: 0.966575	training's binary_logloss: 0.218397	valid_1's auc: 0.961415	valid_1's binary_logloss: 0.233005
# [1000]	training's auc: 0.96956	training's binary_logloss: 0.208047	valid_1's auc: 0.962919	valid_1's binary_logloss: 0.227605
# [1250]	training's auc: 0.972069	training's binary_logloss: 0.199775	valid_1's auc: 0.963883	valid_1's binary_logloss: 0.224244
# [1500]	training's auc: 0.97424	training's binary_logloss: 0.19267	valid_1's auc: 0.964561	valid_1's binary_logloss: 0.221881
# [1750]	training's auc: 0.976135	training's binary_logloss: 0.186368	valid_1's auc: 0.965066	valid_1's binary_logloss: 0.220119
# [2000]	training's auc: 0.977807	training's binary_logloss: 0.180676	valid_1's auc: 0.965424	valid_1's binary_logloss: 0.218842
# [2250]	training's auc: 0.979336	training's binary_logloss: 0.175431	valid_1's auc: 0.965701	valid_1's binary_logloss: 0.217844
# [2500]	training's auc: 0.980695	training's binary_logloss: 0.1707	valid_1's auc: 0.965884	valid_1's binary_logloss: 0.217161
# [2750]	training's auc: 0.981912	training's binary_logloss: 0.166415	valid_1's auc: 0.966001	valid_1's binary_logloss: 0.21672
# [3000]	training's auc: 0.983032	training's binary_logloss: 0.162395	valid_1's auc: 0.96609	valid_1's binary_logloss: 0.216387
# [3250]	training's auc: 0.984069	training's binary_logloss: 0.15858	valid_1's auc: 0.966152	valid_1's binary_logloss: 0.216141
# [3500]	training's auc: 0.985051	training's binary_logloss: 0.154895	valid_1's auc: 0.966207	valid_1's binary_logloss: 0.215924
# [3750]	training's auc: 0.985978	training's binary_logloss: 0.151326	valid_1's auc: 0.966267	valid_1's binary_logloss: 0.215689
# [4000]	training's auc: 0.98681	training's binary_logloss: 0.147982	valid_1's auc: 0.966313	valid_1's binary_logloss: 0.215509
# [4250]	training's auc: 0.987579	training's binary_logloss: 0.144782	valid_1's auc: 0.966354	valid_1's binary_logloss: 0.215349
# [4500]	training's auc: 0.988316	training's binary_logloss: 0.141649	valid_1's auc: 0.966385	valid_1's binary_logloss: 0.215213
# [4750]	training's auc: 0.989028	training's binary_logloss: 0.138578	valid_1's auc: 0.96642	valid_1's binary_logloss: 0.215076
# [5000]	training's auc: 0.989678	training's binary_logloss: 0.135666	valid_1's auc: 0.966453	valid_1's binary_logloss: 0.214962
# Did not meet early stopping. Best iteration is:
# [5000]	training's auc: 0.989678	training's binary_logloss: 0.135666	valid_1's auc: 0.966453	valid_1's binary_logloss: 0.214962
# 00:23:53 INFO: Model training is done after 1855.83s
# 00:25:28 INFO: OOF Accuracy: 0.918544, AUC: 0.966453
# 00:25:31 INFO: Total OOF Accuracy: 0.917786, AUC: 0.966225
